# %%
a=int(input())
b=int(input())
print(max(a,b))

# %%
year = int(input())
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("YES")
else:
    print("NO")

# %%
a = int(input())
b = int(input())

print("YES" if (a == 1) == (b == 1) else "NO")

# %%
import math
a=int(input())
if(a>0):
    print(1)
elif (a<0):
    print(-1)
    
else:
    print(0)
# Out:
#  179
# 1

# %%
a=int(input())
b=int(input())
if(a>b):
    print(1)
elif (a<b):
    print(2)
    
else:
    print(0)
