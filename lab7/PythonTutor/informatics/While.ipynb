# %%
a=int(input())
j=0
i=1
while(j<=a):
   print(i*i)
   i+=1
   j=i*i
# Out:
#  12
# 1
# 4
# 9

# %%
a=int(input())
i=2
while(i<=a):
    if(a%i==0):
        print(i)
        break
    i+=1
# Out:
#  15
# 3

# %%
a=int(input())
i=1

while(i<=a):
    print(i,end=" ")
    i*=2
# Out:
#  50
# 1
# 2
# 4
# 8
# 16
# 32

# %%
a=int(input())
def func(a):
    while(a>1):
        if(a%2!=0):
            print("NO")
            return;
            break
        a/=2
    print("YES")
func(a)
# Out:
#  1
# Yes

# %%
a=int(input())
i=1
s=0
while(i<a):
    i*=2
    s+=1;
print(s)
# Out:
#  7
# 3
