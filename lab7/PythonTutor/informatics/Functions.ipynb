# %%
def func(a,b,c,d):
    return min(a,b,c,d)
a,b,c,d=map(int,input().split())
func(a,b,c,d)
# Out:
#  4 5 6 7
# 4

# %%
def func(a,n):
    return pow(a,n)

a,n=map(int,input().split())
func(a,n)
# Out:
#  2 4
# 16

# %%
def func(x,y):
    return (x!=y) or (not(x==y))
x=int(input())
y=int(input())
func(x,y)
# Out:
#  1
#  0
# True
